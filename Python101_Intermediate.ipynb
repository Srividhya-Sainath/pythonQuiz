# %% [markdown]
# ![hacker (1).png](data:image/png;base64,...)

# %% [markdown]
# ###**Attention, all aspiring Python learners and coding clinicians! Welcome to our Python Quiz!**
# ###**(Level - Intermediate)**

# %% [markdown]
# If you are already aware of how Google colab works, then you could skip these pointers and go ahead with the quiz. But if this is your first time, then lookout for the following things:
#
# *   Make sure the runtime is connected. The notebook shows a green check and ‘Connected’ on the top right corner.
# *   To run cells, press SHIFT + ENTER. Or simply click on this![Screenshot 2024-03-07 at 16.07.07.png](data:image/png;base64,...) botton next to the cell.

# %% [markdown]
# # **Exercise 1**
# Create a function named plot_histogram that takes a list of numbers as input and plots a histogram using matplotlib.
#
# Hint : Use 'import matplotlib.pyplot as plt'

# %%
# Write your code here

# %% [markdown]
# # **Exercise 2**
# Define a function named plot_scatter that takes two lists of numbers as input and plots a scatter plot using matplotlib.

# %%
# Write your code here

# %% [markdown]
# # **Exercise 3**
# Write a function named calculate_and_plot_frequency that takes a string as input. This function should calculate the frequency of each character in the given string (including space) and plot the distribution using a bar plot.
# Hint: Use 'matplotlib.pyplot.bar' to plot your distribution

# %% [markdown]
# Example:
#
# For the input string "*I love Python*", the plot must look something like this -

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Write your code here
